# %%
import importlib
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
from datetime import datetime
from scipy.special import logsumexp

from catboost import Pool, cv, CatBoostClassifier, CatBoostRegressor
from sklearn.metrics import mean_squared_error, classification_report

# %%
train = pd.read_csv("caltech-cs155-2020/train.csv")
test = pd.read_csv("caltech-cs155-2020/test.csv")
df = pd.concat([train,test],sort=False)
print(df.shape)
print(df.columns)
df.tail()
# Out:
# (784239, 28)
# Index(['id', 'last_price', 'mid', 'opened_position_qty ',
#        'closed_position_qty', 'transacted_qty', 'd_open_interest', 'bid1',
#        'bid2', 'bid3', 'bid4', 'bid5', 'ask1', 'ask2', 'ask3', 'ask4', 'ask5',
#        'bid1vol', 'bid2vol', 'bid3vol', 'bid4vol', 'bid5vol', 'ask1vol',
#        'ask2vol', 'ask3vol', 'ask4vol', 'ask5vol', 'y'],
#       dtype='object')
#             id  last_price     mid  opened_position_qty   closed_position_qty  \
# 191854  784234      5150.6  5150.8                   NaN                  NaN
# 191855  784235      5122.6  5122.7                   1.0                  2.0
# 191856  784236      5192.8  5192.3                   NaN                  NaN
# 191857  784237      5152.0  5151.9                   4.0                  2.0
# 191858  784238      5200.0  5200.3                   2.0                  0.0
#
#         transacted_qty  d_open_interest    bid1    bid2    bid3  ...  bid2vol  \
# 191854             0.0                0  5150.6  5150.4  5150.2  ...        5
# 191855             3.0               -1  5122.6  5122.4  5122.2  ...        1
# 191856             0.0                0  5192.0  5191.8  5191.2  ...        2
# 191857             6.0                2  5151.8  5151.6  5151.4  ...        5
# 191858             2.0                2  5200.0  5199.0  5198.8  ...        5
#
#         bid3vol  bid4vol  bid5vol  ask1vol  ask2vol  ask3vol  ask4vol  \
# 191854        3        4        2        1        3        1        3
# 191855        5        1       20       16       17        4        1
# 191856        1        1        1        1        2        1        2
# 191857        6        8       37        7        1        2        1
# 191858        1        2        1        1        1        4        1
#
#         ask5vol   y
# 191854        2 NaN
# 191855       16 NaN
# 191856        1 NaN
# 191857        1 NaN
# 191858        3 NaN
#
# [5 rows x 28 columns]

# %%
bid_cols = ['bid1','bid2', 'bid3', 'bid4', 'bid5']
bid_vol_cols = ['bid1vol', 'bid2vol', 'bid3vol', 'bid4vol', 'bid5vol']
ask_cols = ['ask1', 'ask2', 'ask3', 'ask4', 'ask5',]
ask_vol_cols = ['ask1vol','ask2vol', 'ask3vol', 'ask4vol', 'ask5vol']

group_cols = {"bid_cols":bid_cols,"bid_vol_cols":bid_vol_cols,"ask_cols":ask_cols,"ask_vol_cols":ask_vol_cols}

# %%
for group in group_cols.keys():
    print(group)
    df[f"{group}_max"] = df[group_cols[group]].max(axis=1)
    df[f"{group}_min"] = df[group_cols[group]].min(axis=1)
    df[f"{group}_spread"] = df[f"{group}_max"].div(df[f"{group}_min"])
#     df[f"{group}_logsumexp"] = df[grou/_cols[group]].apply(logsumexp)
    
    df[f"{group}_max"] = df[group_cols[group]].max(axis=1)
    
df["last_price_div__mid"] = df["last_price"].div(df["mid"])
# Out:
# bid_cols
# bid_vol_cols
# ask_cols
# ask_vol_cols

# %%
df["date"] = pd.to_datetime("1.1.2019")
df["date"] = df["date"] + pd.to_timedelta(df["id"]/2,unit="s") # 500 ms per row

df["date"].describe()
# Out:
# count                         784239
# unique                        784239
# top       2019-01-02 14:21:54.500000
# freq                               1
# first            2019-01-01 00:00:00
# last             2019-01-05 12:55:19
# Name: date, dtype: object

# %% [markdown]
# # Fill opened position qty

# %%
train_opq = df.loc[~df['opened_position_qty '].isna()]
print(f"train shape {train.shape[0]}")
test_opq = df.loc[df['opened_position_qty '].isna()]
print(f"test shape {test.shape[0]}")
print(train_opq.shape, test_opq.shape)

X_opq = train_opq.drop(["opened_position_qty ", "closed_position_qty", "d_open_interest","id","date","y"],axis=1)
from scipy import stats
normalized_X_opq = pd.DataFrame(stats.zscore(X_opq, axis=0))
normalized_X_opq.columns = [X_opq.columns]
y_opq = train_opq["opened_position_qty "]

print(normalized_X_opq.shape, y_opq.shape)


test_X_opq = test_opq.drop(["opened_position_qty ", "closed_position_qty", "d_open_interest", "id","date","y"],axis=1)

normalized_test_X_opq = pd.DataFrame(stats.zscore(test_X_opq, axis=0))
normalized_test_X_opq.columns = [test_X_opq.columns]
normalized_test_X_opq.index = test_X_opq.index
print(normalized_test_X_opq.shape)
# Out:
# train shape 592380
# test shape 191859
# (558123, 42) (226116, 42)
# (558123, 36) (558123,)
# (226116, 36)

# %%
from sklearn import linear_model
clf = linear_model.SGDClassifier(max_iter=10, tol=1e-3)
clf.fit(normalized_X_opq, y_opq)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/stochastic_gradient.py:603: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning)
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#        early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='hinge', max_iter=10,
#        n_iter=None, n_iter_no_change=5, n_jobs=None, penalty='l2',
#        power_t=0.5, random_state=None, shuffle=True, tol=0.001,
#        validation_fraction=0.1, verbose=0, warm_start=False)

# %%
pred_opq = clf.predict(normalized_test_X_opq)

# %%
test_opq["opened_position_qty "] = pred_opq
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
train_opq.tail()
# Out:
#             id  last_price     mid  opened_position_qty   closed_position_qty  \
# 191852  784232      5191.8  5191.5                   0.0                  1.0
# 191853  784233      5179.2  5178.6                   1.0                  0.0
# 191855  784235      5122.6  5122.7                   1.0                  2.0
# 191857  784237      5152.0  5151.9                   4.0                  2.0
# 191858  784238      5200.0  5200.3                   2.0                  0.0
#
#         transacted_qty  d_open_interest    bid1    bid2    bid3  ...  \
# 191852             1.0                0  5191.2  5191.0  5190.4  ...
# 191853             1.0                1  5178.2  5178.0  5177.8  ...
# 191855             3.0               -1  5122.6  5122.4  5122.2  ...
# 191857             6.0                2  5151.8  5151.6  5151.4  ...
# 191858             2.0                2  5200.0  5199.0  5198.8  ...
#
#         bid_vol_cols_min  bid_vol_cols_spread  ask_cols_max  ask_cols_min  \
# 191852                 1                 6.00        5192.6        5191.8
# 191853                 1                 3.00        5179.8        5179.0
# 191855                 1                20.00        5123.6        5122.8
# 191857                 4                 9.25        5152.8        5152.0
# 191858                 1                 5.00        5201.6        5200.6
#
#         ask_cols_spread  ask_vol_cols_max  ask_vol_cols_min  \
# 191852         1.000154                 2                 1
# 191853         1.000154                 4                 1
# 191855         1.000156                17                 1
# 191857         1.000155                 7                 1
# 191858         1.000192                 4                 1
#
#         ask_vol_cols_spread  last_price_div__mid                    date
# 191852                  2.0             1.000058 2019-01-05 12:55:16.000
# 191853                  4.0             1.000116 2019-01-05 12:55:16.500
# 191855                 17.0             0.999980 2019-01-05 12:55:17.500
# 191857                  7.0             1.000019 2019-01-05 12:55:18.500
# 191858                  4.0             0.999942 2019-01-05 12:55:19.000
#
# [5 rows x 42 columns]

# %%
df = pd.concat([train_opq,test_opq],sort=False)
df = df.sort_values('id')
print(df.shape)
print(df.columns)
df.tail()
# Out:
# (784239, 42)
# Index(['id', 'last_price', 'mid', 'opened_position_qty ',
#        'closed_position_qty', 'transacted_qty', 'd_open_interest', 'bid1',
#        'bid2', 'bid3', 'bid4', 'bid5', 'ask1', 'ask2', 'ask3', 'ask4', 'ask5',
#        'bid1vol', 'bid2vol', 'bid3vol', 'bid4vol', 'bid5vol', 'ask1vol',
#        'ask2vol', 'ask3vol', 'ask4vol', 'ask5vol', 'y', 'bid_cols_max',
#        'bid_cols_min', 'bid_cols_spread', 'bid_vol_cols_max',
#        'bid_vol_cols_min', 'bid_vol_cols_spread', 'ask_cols_max',
#        'ask_cols_min', 'ask_cols_spread', 'ask_vol_cols_max',
#        'ask_vol_cols_min', 'ask_vol_cols_spread', 'last_price_div__mid',
#        'date'],
#       dtype='object')
#             id  last_price     mid  opened_position_qty   closed_position_qty  \
# 191854  784234      5150.6  5150.8                   0.0                  NaN
# 191855  784235      5122.6  5122.7                   1.0                  2.0
# 191856  784236      5192.8  5192.3                   0.0                  NaN
# 191857  784237      5152.0  5151.9                   4.0                  2.0
# 191858  784238      5200.0  5200.3                   2.0                  0.0
#
#         transacted_qty  d_open_interest    bid1    bid2    bid3  ...  \
# 191854             0.0                0  5150.6  5150.4  5150.2  ...
# 191855             3.0               -1  5122.6  5122.4  5122.2  ...
# 191856             0.0                0  5192.0  5191.8  5191.2  ...
# 191857             6.0                2  5151.8  5151.6  5151.4  ...
# 191858             2.0                2  5200.0  5199.0  5198.8  ...
#
#         bid_vol_cols_min  bid_vol_cols_spread  ask_cols_max  ask_cols_min  \
# 191854                 1                 5.00        5152.4        5151.0
# 191855                 1                20.00        5123.6        5122.8
# 191856                 1                 2.00        5193.4        5192.6
# 191857                 4                 9.25        5152.8        5152.0
# 191858                 1                 5.00        5201.6        5200.6
#
#         ask_cols_spread  ask_vol_cols_max  ask_vol_cols_min  \
# 191854         1.000272                 3                 1
# 191855         1.000156                17                 1
# 191856         1.000154                 2                 1
# 191857         1.000155                 7                 1
# 191858         1.000192                 4                 1
#
#         ask_vol_cols_spread  last_price_div__mid                    date
# 191854                  3.0             0.999961 2019-01-05 12:55:17.000
# 191855                 17.0             0.999980 2019-01-05 12:55:17.500
# 191856                  2.0             1.000096 2019-01-05 12:55:18.000
# 191857                  7.0             1.000019 2019-01-05 12:55:18.500
# 191858                  4.0             0.999942 2019-01-05 12:55:19.000
#
# [5 rows x 42 columns]

# %%
X.shape, y.shape

# %%
import numpy as np
array = np.array(X['last_price'])
order = array.argsort()
ranks = order.argsort()

# %%
ranks

# %%
X['last_price_rank'] = ranks

# %%
X.columns

# %%
from scipy import stats
normalized_X = stats.zscore(X, axis=0)

# %%
normalized_X[:,2]

# %%
pd.DataFrame(data=data[1:,1:],    # values
             columns=data[0,1:])  # 1st row as the column names

normalized_X.tail()

# %%
from sklearn.datasets import load_digits
from sklearn.decomposition import FactorAnalysis
transformer = FactorAnalysis(n_components=40, random_state=0)
X_transformed = transformer.fit_transform(X)
X_transformed.shape

# %%
def get_normalized_X_and_train_y(df, col):
    train_opq = df.loc[~df[col].isna()]
    print(f"train shape {train.shape[0]}")
    test_opq = df.loc[df[col].isna()]
    print(f"test shape {test.shape[0]}")
    print(train_opq.shape, test_opq.shape)

    X_opq = train_opq.drop(["opened_position_qty ", "closed_position_qty", "d_open_interest","id","date","y"],axis=1)
    from scipy import stats
    normalized_X_opq = pd.DataFrame(stats.zscore(X_opq, axis=0))
    normalized_X_opq.columns = [X_opq.columns]
    y_opq = train_opq[col]

    print(normalized_X_opq.shape, y_opq.shape)


    test_X_opq = test_opq.drop(["opened_position_qty ", "closed_position_qty", "d_open_interest", "id","date","y"],axis=1)

    normalized_test_X_opq = pd.DataFrame(stats.zscore(test_X_opq, axis=0))
    normalized_test_X_opq.columns = [test_X_opq.columns]
    normalized_test_X_opq.index = test_X_opq.index
    print(normalized_test_X_opq.shape)
    print(normalized_test_X_opq.columns)
    return normalized_X_opq, y_opq, normalized_test_X_opq

# %%
normalized_X_opq, y_opq, normalized_test_X_opq = get_normalized_X_and_train_y(df, "closed_position_qty")
# Out:
# train shape 592380
# test shape 191859
# (558123, 42) (226116, 42)
# (558123, 36) (558123,)
# (226116, 36)
# MultiIndex([(         'last_price',),
#             (                'mid',),
#             (     'transacted_qty',),
#             (               'bid1',),
#             (               'bid2',),
#             (               'bid3',),
#             (               'bid4',),
#             (               'bid5',),
#             (               'ask1',),
#             (               'ask2',),
#             (               'ask3',),
#             (               'ask4',),
#             (               'ask5',),
#             (            'bid1vol',),
#             (            'bid2vol',),
#             (            'bid3vol',),
#             (            'bid4vol',),
#             (            'bid5vol',),
#             (            'ask1vol',),
#             (            'ask2vol',),
#             (            'ask3vol',),
#             (            'ask4vol',),
#             (            'ask5vol',),
#             (       'bid_cols_max',),
#             (       'bid_cols_min',),
#             (    'bid_cols_spread',),
#             (   'bid_vol_cols_max',),
#             (   'bid_vol_cols_min',),
#             ('bid_vol_cols_spread',),
#             (       'ask_cols_max',),
#             (       'ask_cols_min',),
#             (    'ask_cols_spread',),
#             (   'ask_vol_cols_max',),
#             (   'ask_vol_cols_min',),
#             ('ask_vol_cols_spread',),
#             ('last_price_div__mid',)],
#            )

# %%
def get_df_with_preds_for_nans(df, col):
    from sklearn import linear_model
    clf = linear_model.SGDClassifier(max_iter=10, tol=1e-3)
    clf.fit(normalized_X_opq, y_opq)

    pred_opq = clf.predict(normalized_test_X_opq)
    test_opq[col] = pred_opq
    df = pd.concat([train_opq,test_opq],sort=False)
    df = df.sort_values('id')
    return df

# %%
df = get_df_with_preds_for_nans(df, "closed_position_qty")
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/stochastic_gradient.py:603: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning)

# %%
df
# Out:
#             id  last_price     mid  opened_position_qty   closed_position_qty  \
# 0            0      3842.4  3842.6                  15.0                 14.0
# 1            1      3842.8  3843.4                   6.0                 49.0
# 2            2      3844.0  3844.3                   7.0                 77.0
# 3            3      3843.8  3843.4                   3.0                 34.0
# 4            4      3843.2  3843.1                   3.0                 38.0
# ...        ...         ...     ...                   ...                  ...
# 191854  784234      5150.6  5150.8                   0.0                  1.0
# 191855  784235      5122.6  5122.7                   1.0                  2.0
# 191856  784236      5192.8  5192.3                   0.0                  1.0
# 191857  784237      5152.0  5151.9                   4.0                  2.0
# 191858  784238      5200.0  5200.3                   2.0                  0.0
#
#         transacted_qty  d_open_interest    bid1    bid2    bid3  ...  \
# 0                103.0                0  3842.4  3842.0  3841.8  ...
# 1                 55.0              -43  3843.0  3842.8  3842.4  ...
# 2                 84.0              -69  3843.8  3843.6  3843.2  ...
# 3                 37.0              -30  3843.0  3842.8  3842.4  ...
# 4                 41.0              -35  3842.8  3842.4  3842.0  ...
# ...                ...              ...     ...     ...     ...  ...
# 191854             0.0                0  5150.6  5150.4  5150.2  ...
# 191855             3.0               -1  5122.6  5122.4  5122.2  ...
# 191856             0.0                0  5192.0  5191.8  5191.2  ...
# 191857             6.0                2  5151.8  5151.6  5151.4  ...
# 191858             2.0                2  5200.0  5199.0  5198.8  ...
#
#         bid_vol_cols_min  bid_vol_cols_spread  ask_cols_max  ask_cols_min  \
# 0                      1                14.00        3844.0        3842.8
# 1                      1                11.00        3844.8        3843.8
# 2                      1                21.00        3845.8        3844.8
# 3                      2                 6.50        3844.8        3843.8
# 4                      2                 7.00        3845.0        3843.4
# ...                  ...                  ...           ...           ...
# 191854                 1                 5.00        5152.4        5151.0
# 191855                 1                20.00        5123.6        5122.8
# 191856                 1                 2.00        5193.4        5192.6
# 191857                 4                 9.25        5152.8        5152.0
# 191858                 1                 5.00        5201.6        5200.6
#
#         ask_cols_spread  ask_vol_cols_max  ask_vol_cols_min  \
# 0              1.000312                10                 1
# 1              1.000260                13                 1
# 2              1.000260                16                 1
# 3              1.000260                11                 1
# 4              1.000416                15                 1
# ...                 ...               ...               ...
# 191854         1.000272                 3                 1
# 191855         1.000156                17                 1
# 191856         1.000154                 2                 1
# 191857         1.000155                 7                 1
# 191858         1.000192                 4                 1
#
#         ask_vol_cols_spread  last_price_div__mid                    date
# 0                      10.0             0.999948 2019-01-01 00:00:00.000
# 1                      13.0             0.999844 2019-01-01 00:00:00.500
# 2                      16.0             0.999922 2019-01-01 00:00:01.000
# 3                      11.0             1.000104 2019-01-01 00:00:01.500
# 4                      15.0             1.000026 2019-01-01 00:00:02.000
# ...                     ...                  ...                     ...
# 191854                  3.0             0.999961 2019-01-05 12:55:17.000
# 191855                 17.0             0.999980 2019-01-05 12:55:17.500
# 191856                  2.0             1.000096 2019-01-05 12:55:18.000
# 191857                  7.0             1.000019 2019-01-05 12:55:18.500
# 191858                  4.0             0.999942 2019-01-05 12:55:19.000
#
# [784239 rows x 42 columns]

# %%
df.shape
# Out:
# (784239, 42)

# %%
train = df.loc[~df.y.isna()]
print(f"train shape {train.shape[0]}")
test = df.loc[df.y.isna()]
print(f"test shape {test.shape[0]}")

train_no_nan = train.fillna(-100)
test_no_nan = test.fillna(-100)

# we don't know if the test set has a temporal split, so we'll just try a random split for now
X = train_no_nan.drop(["id","date","y"],axis=1)
y = train_no_nan["y"]
# Out:
# train shape 592380
# test shape 191859

# %%
import torch
import torch.nn as nn
import second_neural_network
importlib.reload(second_neural_network)
model = second_neural_network.second_neural_network()

# %%
import get_average_val_err

importlib.reload(get_average_val_err)

print(get_average_val_err.get_val_err(10, train_no_nan, model))
# Out:
# 592380
# Fold  1  of  10  test indices: [    0     1     2 ... 59235 59236 59237]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.3469
# Train Epoch: 2  Loss: 1.1453
# Train Epoch: 3  Loss: 0.6261
# Train Epoch: 4  Loss: 0.8160
# Train Epoch: 5  Loss: 0.5651
# Train Epoch: 6  Loss: 0.6258
# Train Epoch: 7  Loss: 0.2913
# Train Epoch: 8  Loss: 0.8319
# Train Epoch: 9  Loss: 0.5336
# Train Epoch: 10  Loss: 0.2252
# validation error:  0.6518296787705425
# Fold  2  of  10  test indices: [ 59238  59239  59240 ... 118473 118474 118475]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.6794
# Train Epoch: 2  Loss: 0.5897
# Train Epoch: 3  Loss: 0.3500
# Train Epoch: 4  Loss: 0.4493
# Train Epoch: 5  Loss: 0.3376
# Train Epoch: 6  Loss: 0.9070
# Train Epoch: 7  Loss: 0.8519
# Train Epoch: 8  Loss: 0.5043
# Train Epoch: 9  Loss: 0.2445
# Train Epoch: 10  Loss: 0.7433
# validation error:  0.6618978457365883
# Fold  3  of  10  test indices: [118476 118477 118478 ... 177711 177712 177713]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.7659
# Train Epoch: 2  Loss: 0.6113
# Train Epoch: 3  Loss: 1.3746
# Train Epoch: 4  Loss: 0.6284
# Train Epoch: 5  Loss: 0.9301
# Train Epoch: 6  Loss: 0.3195
# Train Epoch: 7  Loss: 1.2912
# Train Epoch: 8  Loss: 0.2989
# Train Epoch: 9  Loss: 0.7007
# Train Epoch: 10  Loss: 0.5141
# validation error:  0.6661279051390279
# Fold  4  of  10  test indices: [177714 177715 177716 ... 236949 236950 236951]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.5182
# Train Epoch: 2  Loss: 0.3426
# Train Epoch: 3  Loss: 1.1261
# Train Epoch: 4  Loss: 0.6228
# Train Epoch: 5  Loss: 0.7629
# Train Epoch: 6  Loss: 0.9317
# Train Epoch: 7  Loss: 0.6824
# Train Epoch: 8  Loss: 1.2636
# Train Epoch: 9  Loss: 0.7460
# Train Epoch: 10  Loss: 0.5514
# validation error:  0.6719837040406103
# Fold  5  of  10  test indices: [236952 236953 236954 ... 296187 296188 296189]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.6171
# Train Epoch: 2  Loss: 0.3529
# Train Epoch: 3  Loss: 0.4970
# Train Epoch: 4  Loss: 0.5943
# Train Epoch: 5  Loss: 0.7919
# Train Epoch: 6  Loss: 0.7040
# Train Epoch: 7  Loss: 0.6295
# Train Epoch: 8  Loss: 0.4740
# Train Epoch: 9  Loss: 0.9163
# Train Epoch: 10  Loss: 0.3985
# validation error:  0.6686309049646477
# Fold  6  of  10  test indices: [296190 296191 296192 ... 355425 355426 355427]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.6357
# Train Epoch: 2  Loss: 0.2219
# Train Epoch: 3  Loss: 0.8403
# Train Epoch: 4  Loss: 0.4461
# Train Epoch: 5  Loss: 0.3344
# Train Epoch: 6  Loss: 0.2955
# Train Epoch: 7  Loss: 0.3224
# Train Epoch: 8  Loss: 0.9901
# Train Epoch: 9  Loss: 1.4260
# Train Epoch: 10  Loss: 0.3450
# validation error:  0.655410232082762
# Fold  7  of  10  test indices: [355428 355429 355430 ... 414663 414664 414665]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.3910
# Train Epoch: 2  Loss: 0.5314
# Train Epoch: 3  Loss: 0.5932
# Train Epoch: 4  Loss: 0.6818
# Train Epoch: 5  Loss: 0.9573
# Train Epoch: 6  Loss: 0.4194
# Train Epoch: 7  Loss: 0.4805
# Train Epoch: 8  Loss: 0.7144
# Train Epoch: 9  Loss: 0.6957
# Train Epoch: 10  Loss: 0.5300
# validation error:  0.6597541193617457
# Fold  8  of  10  test indices: [414666 414667 414668 ... 473901 473902 473903]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.6422
# Train Epoch: 2  Loss: 0.9367
# Train Epoch: 3  Loss: 0.6984
# Train Epoch: 4  Loss: 0.3210
# Train Epoch: 5  Loss: 0.6287
# Train Epoch: 6  Loss: 0.6323
# Train Epoch: 7  Loss: 0.4559
# Train Epoch: 8  Loss: 0.3224
# Train Epoch: 9  Loss: 0.3702
# Train Epoch: 10  Loss: 0.6399
# validation error:  0.6595938916982024
# Fold  9  of  10  test indices: [473904 473905 473906 ... 533139 533140 533141]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.3703
# Train Epoch: 2  Loss: 0.4254
# Train Epoch: 3  Loss: 0.6471
# Train Epoch: 4  Loss: 0.4558
# Train Epoch: 5  Loss: 0.3046
# Train Epoch: 6  Loss: 0.8177
# Train Epoch: 7  Loss: 0.3848
# Train Epoch: 8  Loss: 1.0243
# Train Epoch: 9  Loss: 0.2906
# Train Epoch: 10  Loss: 0.3154
# validation error:  0.6570055778352015
# Fold  10  of  10  test indices: [533142 533143 533144 ... 592377 592378 592379]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.5811
# Train Epoch: 2  Loss: 0.3506
# Train Epoch: 3  Loss: 0.9447
# Train Epoch: 4  Loss: 0.5492
# Train Epoch: 5  Loss: 1.1781
# Train Epoch: 6  Loss: 0.6141
# Train Epoch: 7  Loss: 0.5079
# Train Epoch: 8  Loss: 0.1963
# Train Epoch: 9  Loss: 0.3490
# Train Epoch: 10  Loss: 0.7588
# validation error:  0.6442886636749426
# (0.6596522523304271, 6.0190359144538725e-05, [0.6518296787705425, 0.6618978457365883, 0.6661279051390279, 0.6719837040406103, 0.6686309049646477, 0.655410232082762, 0.6597541193617457, 0.6595938916982024, 0.6570055778352015, 0.6442886636749426])

# %%
## export predictions

# test["Predicted"] = model.predict(test.drop(["id","date","y"],axis=1),prediction_type='Probability')[:,1]
test["Predicted"] = model.predict(test_no_nan.drop(["id","date","y"],axis=1))
test[["id","Predicted"]].to_csv("submission_test_fill_nans_second_neural_network1.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-ffd6d1ddab6c> in <module>()
#       2
#       3 # test["Predicted"] = model.predict(test.drop(["id","date","y"],axis=1),prediction_type='Probability')[:,1]
# ----> 4 test["Predicted"] = model.predict(test.drop(["id","date","y"],axis=1))
#       5 test[["id","Predicted"]].to_csv("submission_test_fill_nans_second_neural_network1.csv",index=False)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3992             level=level,
#    3993             inplace=inplace,
# -> 3994             errors=errors,
#    3995         )
#    3996
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3933         for axis, labels in axes.items():
#    3934             if labels is not None:
# -> 3935                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3936
#    3937         if inplace:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3967                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3968             else:
# -> 3969                 new_axis = axis.drop(labels, errors=errors)
#    3970             result = self.reindex(**{axis_name: new_axis})
#    3971
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['date' 'y'] not found in axis"
