# %%
import importlib
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
from datetime import datetime
from scipy.special import logsumexp

from catboost import Pool, cv, CatBoostClassifier, CatBoostRegressor
from sklearn.metrics import mean_squared_error, classification_report

# %%
train = pd.read_csv("caltech-cs155-2020/train.csv")
test = pd.read_csv("caltech-cs155-2020/test.csv")
df = pd.concat([train,test],sort=False)
print(df.shape)
print(df.columns)
df.tail()
# Out:
# (784239, 28)
# Index(['id', 'last_price', 'mid', 'opened_position_qty ',
#        'closed_position_qty', 'transacted_qty', 'd_open_interest', 'bid1',
#        'bid2', 'bid3', 'bid4', 'bid5', 'ask1', 'ask2', 'ask3', 'ask4', 'ask5',
#        'bid1vol', 'bid2vol', 'bid3vol', 'bid4vol', 'bid5vol', 'ask1vol',
#        'ask2vol', 'ask3vol', 'ask4vol', 'ask5vol', 'y'],
#       dtype='object')
#             id  last_price     mid  opened_position_qty   closed_position_qty  \
# 191854  784234      5150.6  5150.8                   NaN                  NaN
# 191855  784235      5122.6  5122.7                   1.0                  2.0
# 191856  784236      5192.8  5192.3                   NaN                  NaN
# 191857  784237      5152.0  5151.9                   4.0                  2.0
# 191858  784238      5200.0  5200.3                   2.0                  0.0
#
#         transacted_qty  d_open_interest    bid1    bid2    bid3  ...  bid2vol  \
# 191854             0.0                0  5150.6  5150.4  5150.2  ...        5
# 191855             3.0               -1  5122.6  5122.4  5122.2  ...        1
# 191856             0.0                0  5192.0  5191.8  5191.2  ...        2
# 191857             6.0                2  5151.8  5151.6  5151.4  ...        5
# 191858             2.0                2  5200.0  5199.0  5198.8  ...        5
#
#         bid3vol  bid4vol  bid5vol  ask1vol  ask2vol  ask3vol  ask4vol  \
# 191854        3        4        2        1        3        1        3
# 191855        5        1       20       16       17        4        1
# 191856        1        1        1        1        2        1        2
# 191857        6        8       37        7        1        2        1
# 191858        1        2        1        1        1        4        1
#
#         ask5vol   y
# 191854        2 NaN
# 191855       16 NaN
# 191856        1 NaN
# 191857        1 NaN
# 191858        3 NaN
#
# [5 rows x 28 columns]

# %%
bid_cols = ['bid1','bid2', 'bid3', 'bid4', 'bid5']
bid_vol_cols = ['bid1vol', 'bid2vol', 'bid3vol', 'bid4vol', 'bid5vol']
ask_cols = ['ask1', 'ask2', 'ask3', 'ask4', 'ask5',]
ask_vol_cols = ['ask1vol','ask2vol', 'ask3vol', 'ask4vol', 'ask5vol']

group_cols = {"bid_cols":bid_cols,"bid_vol_cols":bid_vol_cols,"ask_cols":ask_cols,"ask_vol_cols":ask_vol_cols}

# %%
for group in group_cols.keys():
    print(group)
    df[f"{group}_max"] = df[group_cols[group]].max(axis=1)
    df[f"{group}_min"] = df[group_cols[group]].min(axis=1)
    df[f"{group}_spread"] = df[f"{group}_max"].div(df[f"{group}_min"])
#     df[f"{group}_logsumexp"] = df[grou/_cols[group]].apply(logsumexp)
    
    df[f"{group}_max"] = df[group_cols[group]].max(axis=1)
    
df["last_price_div__mid"] = df["last_price"].div(df["mid"])
# Out:
# bid_cols
# bid_vol_cols
# ask_cols
# ask_vol_cols

# %%
df["date"] = pd.to_datetime("1.1.2019")
df["date"] = df["date"] + pd.to_timedelta(df["id"]/2,unit="s") # 500 ms per row

df["date"].describe()
# Out:
# count                         784239
# unique                        784239
# top       2019-01-02 14:21:54.500000
# freq                               1
# first            2019-01-01 00:00:00
# last             2019-01-05 12:55:19
# Name: date, dtype: object

# %%
train = df.loc[~df.y.isna()]
print(f"train shape {train.shape[0]}")
test = df.loc[df.y.isna()]
print(f"test shape {test.shape[0]}")
# Out:
# train shape 592380
# test shape 191859

# %%
train_no_nan = train.fillna(-100)
test_no_nan = test.fillna(-100)

# %%
# we don't know if the test set has a temporal split, so we'll just try a random split for now
X = train_no_nan.drop(["id","date","y"],axis=1)
y = train_no_nan["y"]

# %%
X
# Out:
#         last_price     mid  opened_position_qty   closed_position_qty  \
# 0           3842.4  3842.6                -100.0               -100.0
# 1           3842.8  3843.4                   6.0                 49.0
# 2           3844.0  3844.3                   7.0                 77.0
# 3           3843.8  3843.4                   3.0                 34.0
# 4           3843.2  3843.1                   3.0                 38.0
# ...            ...     ...                   ...                  ...
# 592375      4110.2  4110.3                   1.0                  1.0
# 592376      4109.4  4110.5                   6.0                  5.0
# 592377      4109.4  4110.5                -100.0               -100.0
# 592378      4109.4  4110.5                -100.0               -100.0
# 592379      4109.4  4110.5                -100.0               -100.0
#
#         transacted_qty  d_open_interest    bid1    bid2    bid3    bid4  ...  \
# 0                103.0                0  3842.4  3842.0  3841.8  3841.0  ...
# 1                 55.0              -43  3843.0  3842.8  3842.4  3842.0  ...
# 2                 84.0              -69  3843.8  3843.6  3843.2  3843.0  ...
# 3                 37.0              -30  3843.0  3842.8  3842.4  3842.0  ...
# 4                 41.0              -35  3842.8  3842.4  3842.0  3841.8  ...
# ...                ...              ...     ...     ...     ...     ...  ...
# 592375             2.0                1  4110.2  4110.0  4109.4  4109.2  ...
# 592376            11.0                1  4109.2  4109.0  4108.6  4108.2  ...
# 592377             0.0                0  4109.2  4109.0  4108.6  4108.2  ...
# 592378             0.0                0  4109.2  4109.0  4108.6  4108.2  ...
# 592379             0.0                0  4109.2  4109.0  4108.6  4108.2  ...
#
#         bid_vol_cols_max  bid_vol_cols_min  bid_vol_cols_spread  ask_cols_max  \
# 0                     14                 1                 14.0        3844.0
# 1                     11                 1                 11.0        3844.8
# 2                     21                 1                 21.0        3845.8
# 3                     13                 2                  6.5        3844.8
# 4                     14                 2                  7.0        3845.0
# ...                  ...               ...                  ...           ...
# 592375                 3                 1                  3.0        4112.6
# 592376                 6                 2                  3.0        4113.0
# 592377                 6                 2                  3.0        4113.0
# 592378                 6                 2                  3.0        4113.0
# 592379                 6                 2                  3.0        4113.0
#
#         ask_cols_min  ask_cols_spread  ask_vol_cols_max  ask_vol_cols_min  \
# 0             3842.8         1.000312                10                 1
# 1             3843.8         1.000260                13                 1
# 2             3844.8         1.000260                16                 1
# 3             3843.8         1.000260                11                 1
# 4             3843.4         1.000416                15                 1
# ...              ...              ...               ...               ...
# 592375        4110.4         1.000535                10                 2
# 592376        4111.8         1.000292                 9                 3
# 592377        4111.8         1.000292                 9                 3
# 592378        4111.8         1.000292                 9                 3
# 592379        4111.8         1.000292                 9                 3
#
#         ask_vol_cols_spread  last_price_div__mid
# 0                      10.0             0.999948
# 1                      13.0             0.999844
# 2                      16.0             0.999922
# 3                      11.0             1.000104
# 4                      15.0             1.000026
# ...                     ...                  ...
# 592375                  5.0             0.999976
# 592376                  3.0             0.999732
# 592377                  3.0             0.999732
# 592378                  3.0             0.999732
# 592379                  3.0             0.999732
#
# [592380 rows x 39 columns]

# %%
X.shape, y.shape
# Out:
# ((592380, 39), (592380,))

# %%
from sklearn.datasets import load_digits
from sklearn.decomposition import FactorAnalysis
X, y = load_digits(return_X_y=True)
transformer = FactorAnalysis(n_components=7, random_state=0)
X_transformed = transformer.fit_transform(X)
X_transformed.shape
# Out:
# (1797, 7)

# %%
X.shape
# Out:
# (1797, 64)

# %%
y.shape
# Out:
# (1797,)

# %%
import torch
import torch.nn as nn
import second_neural_network
importlib.reload(second_neural_network)
model = second_neural_network.second_neural_network()

# %%
import get_average_val_err

importlib.reload(get_average_val_err)

print(get_average_val_err.get_val_err(10, train_no_nan, model))
# Out:
# 592380
# Fold  1  of  10  test indices: [    0     1     2 ... 59235 59236 59237]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.0091
# Train Epoch: 2  Loss: 0.5524
# Train Epoch: 3  Loss: 0.3352
# Train Epoch: 4  Loss: 0.4086
# Train Epoch: 5  Loss: 0.5421
# validation error:  0.6485635727480674
# Fold  2  of  10  test indices: [ 59238  59239  59240 ... 118473 118474 118475]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 1.6097
# Train Epoch: 2  Loss: 0.6599
# Train Epoch: 3  Loss: 0.2742
# Train Epoch: 4  Loss: 0.2478
# Train Epoch: 5  Loss: 0.8830
# validation error:  0.6534842077788663
# Fold  3  of  10  test indices: [118476 118477 118478 ... 177711 177712 177713]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.9412
# Train Epoch: 2  Loss: 0.8627
# Train Epoch: 3  Loss: 0.1922
# Train Epoch: 4  Loss: 0.5959
# Train Epoch: 5  Loss: 0.7785
# validation error:  0.6551097842149405
# Fold  4  of  10  test indices: [177714 177715 177716 ... 236949 236950 236951]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.5596
# Train Epoch: 2  Loss: 0.5641
# Train Epoch: 3  Loss: 0.4854
# Train Epoch: 4  Loss: 0.3043
# Train Epoch: 5  Loss: 1.3132
# validation error:  0.6688827110316258
# Fold  5  of  10  test indices: [236952 236953 236954 ... 296187 296188 296189]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.4842
# Train Epoch: 2  Loss: 0.4020
# Train Epoch: 3  Loss: 0.4570
# Train Epoch: 4  Loss: 0.5817
# Train Epoch: 5  Loss: 0.7984
# validation error:  0.6642354004033706
# Fold  6  of  10  test indices: [296190 296191 296192 ... 355425 355426 355427]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.6708
# Train Epoch: 2  Loss: 0.1052
# Train Epoch: 3  Loss: 0.3153
# Train Epoch: 4  Loss: 0.4310
# Train Epoch: 5  Loss: 0.2770
# validation error:  0.6494744395997384
# Fold  7  of  10  test indices: [355428 355429 355430 ... 414663 414664 414665]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.3805
# Train Epoch: 2  Loss: 0.2867
# Train Epoch: 3  Loss: 0.3363
# Train Epoch: 4  Loss: 0.7297
# Train Epoch: 5  Loss: 0.3210
# validation error:  0.6563100829607003
# Fold  8  of  10  test indices: [414666 414667 414668 ... 473901 473902 473903]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 1.3421
# Train Epoch: 2  Loss: 0.5445
# Train Epoch: 3  Loss: 0.5516
# Train Epoch: 4  Loss: 0.8216
# Train Epoch: 5  Loss: 0.3798
# validation error:  0.6552986061567039
# Fold  9  of  10  test indices: [473904 473905 473906 ... 533139 533140 533141]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 1.2039
# Train Epoch: 2  Loss: 0.6116
# Train Epoch: 3  Loss: 0.2465
# Train Epoch: 4  Loss: 0.2926
# Train Epoch: 5  Loss: 0.2716
# validation error:  0.6507565698748374
# Fold  10  of  10  test indices: [533142 533143 533144 ... 592377 592378 592379]
# len(val_index_list):  59238
# Train Epoch: 1  Loss: 0.4109
# Train Epoch: 2  Loss: 0.4758
# Train Epoch: 3  Loss: 0.2230
# Train Epoch: 4  Loss: 0.9325
# Train Epoch: 5  Loss: 0.7112
# validation error:  0.6380980605833875
# (0.6540213435352238, 6.482014318462946e-05, [0.6485635727480674, 0.6534842077788663, 0.6551097842149405, 0.6688827110316258, 0.6642354004033706, 0.6494744395997384, 0.6563100829607003, 0.6552986061567039, 0.6507565698748374, 0.6380980605833875])

# %%
test["Predicted"] = model.predict(test_no_nan.drop(["id","date","y"],axis=1))
test[["id","Predicted"]].to_csv("submission_test_second_neural_network2.csv",index=False)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
X_transformed
# Out:
# array([[-0.10390271,  0.28198204,  1.93908236, ..., -0.38873227,
#         -0.30377059,  0.7951861 ],
#        [-0.96261823,  0.18862239, -1.73202491, ..., -0.02628507,
#         -0.33583478, -1.4748951 ],
#        [-1.07572294, -0.31865454, -1.38943619, ..., -0.99384465,
#         -0.52678795,  0.52332889],
#        ...,
#        [-0.68171725,  0.05397779, -0.80913822, ..., -0.01853757,
#         -0.92232969, -0.28710684],
#        [-0.34632883, -0.12407529,  1.22216715, ...,  0.21910061,
#         -0.29530191, -0.7910442 ],
#        [ 0.66672038, -0.92771996, -0.0150591 , ..., -0.84866807,
#          0.21509133,  0.51120728]])

# %%
transformer = FactorAnalysis(n_components=64, random_state=0)
X_transformed = transformer.fit_transform(X)
X_transformed.shape
# Out:
# (1797, 64)

# %%
X_transformed
# Out:
# array([[-0.06488965,  1.65622217, -0.78845486, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.57454077, -1.62102338,  0.36935249, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.51612897, -0.77575138,  0.24773356, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.79600586, -0.55058492,  0.47146544, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.33631286,  0.97600191, -0.85748027, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.0298756 ,  0.49774478,  0.8988633 , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
X
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
import numpy as np
array = np.array([4,2,7,1])
order = array.argsort()
ranks = order.argsort()

# %%
ranks.reshape((-1,1))
# Out:
# array([[2],
#        [1],
#        [3],
#        [0]])
